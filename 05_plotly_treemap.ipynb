# %% [markdown]
# # Master BigData UCM 2023

# %% [markdown]
# ## 1. Datos vehículos a la venta 2016 en UK
#
# Propósito:
#
# - Generar un treemap interactivo usando la librería plotly

# %%
import pandas as pd

import plotly.express as px

# %% [markdown]
# ### Carga de datos
#
# Este dataset tiene ya 7 años pero sigue siendo válido para nuestro propósito.
#
# La principal ventaja es que tiene una variale de grupo (o "factor") creada en español (la variable "Tipo") para facilitar los gráficos por tipo de vehículo.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df= pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/datos_vehiculos_2016.pkl")

# %%
df.shape
# Out:
# (4490, 20)

# %%
df.describe(include = 'all')
# Out:
#        Manufacturer  Model  EngineCapacity FuelType  MetricUrbanCold  \
# count          4490   4490     4490.000000     4490      4459.000000
# unique           44    450             NaN        7              NaN
# top             BMW  Coupe             NaN   Diesel              NaN
# freq            607    260             NaN     2274              NaN
# mean            NaN    NaN     1991.111804      NaN         6.925252
# std             NaN    NaN      828.057573      NaN         2.800404
# min             NaN    NaN      647.000000      NaN         0.000000
# 25%             NaN    NaN     1499.000000      NaN         5.200000
# 50%             NaN    NaN     1968.000000      NaN         6.100000
# 75%             NaN    NaN     1997.000000      NaN         7.700000
# max             NaN    NaN     6752.000000      NaN        25.600000
#
#         MetricExtraUrban  MetricCombined  ImperialUrbanCold  \
# count        4459.000000     4490.000000        4459.000000
# unique               NaN             NaN                NaN
# top                  NaN             NaN                NaN
# freq                 NaN             NaN                NaN
# mean            4.790491        5.549042          45.364230
# std             1.224893        1.794549          12.962089
# min             0.000000        0.600000           0.000000
# 25%             4.000000        4.400000          36.700000
# 50%             4.500000        5.100000          46.300000
# 75%             5.300000        6.100000          54.300000
# max            11.800000       16.300000          97.400000
#
#         ImperialExtraUrban  ImperialCombined       CO2gkm  FuelCost12000Miles  \
# count          4459.000000       4490.000000  4490.000000         4490.000000
# unique                 NaN               NaN          NaN                 NaN
# top                    NaN               NaN          NaN                 NaN
# freq                   NaN               NaN          NaN                 NaN
# mean             62.014891         55.120445   135.823163         1086.980401
# std              12.771535         15.869631    39.732306          348.519954
# min               0.000000         17.300000    13.000000          117.000000
# 25%              53.300000         46.300000   112.000000          867.000000
# 50%              62.800000         55.400000   127.000000          999.500000
# 75%              70.600000         64.200000   149.000000         1202.000000
# max             104.600000        470.800000   380.000000         3185.000000
#
#         EuroStandard  NoiseLeveldBA  EmissionsCOmgkm  THCEmissionsmgkm  \
# count         4490.0    4490.000000      4490.000000       2230.000000
# unique           NaN            NaN              NaN               NaN
# top              NaN            NaN              NaN               NaN
# freq             NaN            NaN              NaN               NaN
# mean             6.0      71.302249       260.113007         41.636726
# std              0.0       1.969812       143.096498         14.819350
# min              6.0      66.000000        10.000000          4.000000
# 25%              6.0      70.000000       156.000000         33.000000
# 50%              6.0      71.000000       230.000000         41.000000
# 75%              6.0      73.000000       329.000000         49.000000
# max              6.0      76.000000       913.000000        412.000000
#
#         EmissionsNOxmgkm  THC+NOxEmissionsmgkm  ParticulatesNo_mgkm    Tipo
# count        4490.000000           2289.000000          2293.000000    4490
# unique               NaN                   NaN                  NaN       3
# top                  NaN                   NaN                  NaN  Diesel
# freq                 NaN                   NaN                  NaN    2274
# mean           37.138886             80.458934             0.300039     NaN
# std            18.805169             22.962894             0.331194     NaN
# min             1.000000             19.000000             0.000000     NaN
# 25%            23.000000             66.000000             0.060000     NaN
# 50%            36.000000             81.000000             0.180000     NaN
# 75%            52.000000             97.000000             0.480000     NaN
# max           169.000000            163.000000             3.050000     NaN

# %%
count_tipo = pd.value_counts(df['Tipo'], sort = True)
count_tipo
# Out:
# Diesel      2274
# Gasolina    2095
# HEV          121
# Name: Tipo, dtype: int64

# %%
count_manufacturer = pd.value_counts(df['Manufacturer'], sort = True)
count_manufacturer
# Out:
# BMW                     607
# AUDI                    514
# MERCEDES-BENZ           436
# FORD                    362
# VOLKSWAGEN              340
# SKODA                   223
# VAUXHALL                206
# MINI                    167
# KIA                     152
# SEAT                    126
# VOLVO                   120
# PORSCHE                 101
# PEUGEOT                  99
# TOYOTA                   95
# RENAULT                  86
# VOLKSWAGEN C.V.          83
# CITROEN                  78
# LEXUS                    54
# NISSAN                   53
# CHRYSLER JEEP            50
# FIAT                     49
# HYUNDAI                  49
# DS                       46
# MAZDA                    40
# JAGUAR                   38
# INFINITI                 37
# HONDA                    35
# SSANGYONG                33
# LAND ROVER               26
# SUZUKI                   24
# SUBARU                   22
# McLaren                  18
# SMART                    16
# BENTLEY MOTORS           15
# ALFA ROMEO               14
# DACIA                    14
# ASTON MARTIN LAGONDA     13
# ABARTH                   11
# MITSUBISHI               11
# FERRARI                  10
# Rolls Royce               8
# MASERATI                  6
# LAMBORGHINI               2
# LONDON TAXI COMPANY       1
# Name: Manufacturer, dtype: int64

# %% [markdown]
# # Preparación de tabla para treemap

# %%
para_treemap = df[["Manufacturer",
                   "Tipo"]].value_counts()

# %%
para_treemap
# Out:
# Manufacturer         Tipo
# BMW                  Diesel      333
# AUDI                 Diesel      298
# BMW                  Gasolina    261
# FORD                 Diesel      216
# MERCEDES-BENZ        Diesel      214
#                                 ...
# MASERATI             Diesel        2
# DS                   HEV           1
# LONDON TAXI COMPANY  Diesel        1
# MITSUBISHI           HEV           1
# LAND ROVER           HEV           1
# Length: 90, dtype: int64

# %%
para_tree2 = para_treemap.reset_index(name = "count")

# %%
para_tree2
# Out:
#            Manufacturer      Tipo  count
# 0                   BMW    Diesel    333
# 1                  AUDI    Diesel    298
# 2                   BMW  Gasolina    261
# 3                  FORD    Diesel    216
# 4         MERCEDES-BENZ    Diesel    214
# ..                  ...       ...    ...
# 85             MASERATI    Diesel      2
# 86                   DS       HEV      1
# 87  LONDON TAXI COMPANY    Diesel      1
# 88           MITSUBISHI       HEV      1
# 89           LAND ROVER       HEV      1
#
# [90 rows x 3 columns]

# %%
para_tree2.dtypes
# Out:
# Manufacturer    object
# Tipo            object
# count            int64
# dtype: object

# %%
# plot it
fig = px.treemap(para_tree2,
                 path = ['Tipo', 'Manufacturer'],
                values = 'count')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="
GEN","Diesel\u002fVOLKSWAGEN C.V.","Gasolina\u002fVOLKSWAGEN C.V.","Diesel\u002fVOLVO","Gasolina\u002fVOLVO","HEV\u002fVOLVO","Diesel","Gasolina","HEV"],"labels":["ABARTH","ALFA ROMEO","ALFA ROMEO","ASTON MARTIN LAGONDA","AUDI","AUDI","AUDI","BENTLEY MOTORS","BMW","BMW","BMW","CHRYSLER JEEP","CHRYSLER JEEP","CITROEN","CITROEN","DACIA","DACIA","DS","DS","DS","FERRARI","FIAT","FIAT","FORD","FORD","HONDA","HONDA","HYUNDAI","HYUNDAI","INFINITI","INFINITI","INFINITI","JAGUAR","JAGUAR","KIA","KIA","LAMBORGHINI","LAND ROVER","LAND ROVER","LAND ROVER","LEXUS","LEXUS","LONDON TAXI COMPANY","MASERATI","MASERATI","MAZDA","MAZDA","MERCEDES-BENZ","MERCEDES-BENZ","MERCEDES-BENZ","MINI","MINI","MITSUBISHI","MITSUBISHI","MITSUBISHI","McLaren","NISSAN","NISSAN","PEUGEOT","PEUGEOT","PORSCHE","PORSCHE","PORSCHE","RENAULT","RENAULT","Rolls Royce","SEAT","SEAT","SKODA","SKODA","SMART","SSANGYONG","SSANGYONG","SUBARU","SUBARU","SUZUKI","SUZUKI","TOYOTA","TOYOTA","TOYOTA","VAUXHALL","VAUXHALL","VOLKSWAGEN","VOLKSWAGEN","VOLKSWAGEN","VOLKSWAGEN C.V.","VOLKSWAGEN C.V.","VOLVO","VOLVO","VOLVO","Diesel","Gasolina","HEV"],"name":"","parents":["Gasolina","Diesel","Gasolina","Gasolina","Diesel","Gasolina","HEV","Gasolina","Diesel","Gasolina","HEV","Diesel","Gasolina","Diesel","Gasolina","Diesel" ...

# %%
import numpy as np
df = px.data.gapminder().query("year == 2007")
fig = px.treemap(df, path=[px.Constant("world"), 'continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="151422d8-ed0e-4eee-a679-7f8380b1ac8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("151422d8-ed0e-4eee-a679-7f8380b1ac8e")) {                    Plotly.newPlot(                        "151422d8-ed0e-4eee-a679-7f8380b1ac8e",                        [{"branchvalues":"total","customdata":[["AFG",43.828],["ALB",76.423],["DZA",72.301],["AGO",42.731],["ARG",75.32],["AUS",81.235],["AUT",79.829],["BHR",75.635],["BGD",64.062],["BEL",79.441],["BEN",56.728],["BOL",65.554],["BIH",74.852],["BWA",50.728],["BRA",72.39],["BGR",73.005],["BFA",52.295],["BDI",49.58],["KHM",59.723],["CMR",50.43],["CAN",80.65300000000002],["CAF",44.74100000000001],["TCD",50.651],["CHL",78.553],["CHN",72.961],["COL",72.889],["COM",65.152],["COD",46.462],["COG",55.322],["CRI",78.782],["CIV",48.328],["HRV",75.748],["CUB",78.273],["CZE",76.486],["DN
# %%
df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# 35         DZA       12
# 47         AGO       24
# 59         ARG       32
# ...        ...      ...
# 1655       VNM      704
# 1667       PSE      275
# 1679       YEM      887
# 1691       ZMB      894
# 1703       ZWE      716
#
# [142 rows x 8 columns]

# %% [markdown]
# Buscamos una escala de color para nuestro propósito.
#
# Lista completa aquí:
#
# https://matplotlib.org/stable/gallery/color/colormap_reference.html

# %%
# plot it
fig = px.treemap(para_tree2,
                 path = ['Tipo', 'Manufacturer'],
                 values = 'count',
                 color='count',
                 color_continuous_scale='RdPu')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ccc23b7d-f3a7-4265-8850-887512dc882f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccc23b7d-f3a7-4265-8850-887512dc882f")) {                    Plotly.newPlot(                        "ccc23b7d-f3a7-4265-8850-887512dc882f",                        [{"branchvalues":"total","customdata":[[11.0],[4.0],[10.0],[13.0],[298.0],[212.0],[4.0],[15.0],[333.0],[261.0],[13.0],[26.0],[24.0],[45.0],[33.0],[5.0],[9.0],[23.0],[22.0],[1.0],[10.0],[25.0],[24.0],[216.0],[146.0],[12.0],[23.0],[27.0],[22.0],[18.0],[16.0],[3.0],[19.0],[19.0],[81.0],[71.0],[2.0],[16.0],[9.0],[1.0],[11.0],[43.0],[1.0],[2.0],[4.0],[25.0],[15.0],[214.0],[202.0],[20.0],[68.0],[99.0],[7.0],[3.0],[1.0],[18.0],[22.0],[31.0],[59.0],[40.0],[3.0],[96.0],[2.0],[44.0],[42.0],[8.0],[57.0],[69.0],[127.0],[96.0],[16.0],[28.0],[5.0],[11.0],[11.0],[4.0],[20.0],[26.0],[44.0],[25.0],[65.0],[141.0],[197.0],[140.0],[3.0],[75.0],[8.0],[91.0],[24.0],[5.0],[173.06244503078275],[127.15942720763724],[25.694214876033058]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003ecount=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Gasolina\u002fABARTH","Diesel\u002fALFA ROMEO","Gasolina\u002fALFA ROMEO","Gasolina\u002fASTON MARTIN LAGONDA","Diesel\u002fAUDI","Gasolina\u002fAUDI","HEV\u002fAUDI","Gasolina\u002fBENTLEY MOTORS","Diesel\u002fBMW","Gasolina\u002fBMW","HEV\u002fBMW","Diesel\u002fCHRYSLER JEEP","Gasolina\u